# %% [markdown]
# # Bounded Agent\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom ai_saas.agents import run_bounded_agent\nprint(run_bounded_agent("refund",{"lookup","refund"},True,False));print(run_bounded_agent("refund",{"lookup","refund"},True,True))
