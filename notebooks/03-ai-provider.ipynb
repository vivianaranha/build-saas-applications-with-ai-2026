# %% [markdown]
# # AI Provider Gateway\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom ai_saas.provider import MockProvider\nprint(MockProvider().generate("summarize a customer ticket"))
