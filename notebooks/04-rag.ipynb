# %% [markdown]
# # Tenant-Aware RAG\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nimport json\nfrom pathlib import Path\nfrom ai_saas.retrieval import retrieve\ndocs=json.loads((Path.cwd().parent/"data/knowledge.json").read_text());print(retrieve("refund policy",docs,tenant="t1"))
